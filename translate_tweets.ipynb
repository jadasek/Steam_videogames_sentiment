# %%
import pandas as pd
import translators as ts
from tqdm.notebook import tqdm
import time

data = pd.read_excel("export_dataframe.xlsx")
#display(data)
for i in tqdm(range(len(data.index))):
    if data.iloc[i]['language'] != 'en':
        data.at[i, 'content'] = ts.translate_text(data.iloc[i]['content'], to_language='en', translator='google')
        time.sleep(0.1)
display(data)

data.to_excel('export_dataframe_translated.xlsx', index=False)
# Out:
#   0%|          | 0/496 [00:00<?, ?it/s]
#                    date                   id  \
# 0   2023-03-29 11:21:37  1641037892955913984
# 1   2023-03-29 11:21:03  1641037748957221120
# 2   2023-03-29 11:20:50  1641037696683639040
# 3   2023-03-29 11:19:11  1641037280881283072
# 4   2023-03-29 11:17:28  1641036849668932096
# ..                  ...                  ...
# 491 2023-03-28 15:38:54  1640740251768439040
# 492 2023-03-28 15:36:42  1640739700246715904
# 493 2023-03-28 15:35:51  1640739487171976960
# 494 2023-03-28 15:33:21  1640738855082136064
# 495 2023-03-28 15:30:59  1640738259859824896
#
#                                                content         username  \
# 0                                       Langguth plums  Hi1PmYjX1jAiJZY
# 1                                   Khada early autumn  i6w83RgcPeN2Iew
# 2                                     NOA Kasayama Pig     xboy44215910
# 3                                     Hikkel check out  Hi1PmYjX1jAiJZY
# 4                                svirezhev quinault mg     xboy44215910
# ..                                                 ...              ...
# 491  been playing a lot of halo infinite season 3 a...       bbkdragoon
# 492  i got so wrapped up in the csgo value that i d...           TJ_DGF
# 493  for everyone who doesnt understand german its ...      Lurker_csgo
# 494  petr fame bolyshev professional csgo player fo...        altkoshka
# 495                            love being back on csgo          Xed_fps
#
#      like_count  retweet_count language
# 0            13             13       in
# 1            16             16       et
# 2            14             14      und
# 3            16             16       et
# 4            13             13      und
# ..          ...            ...      ...
# 491          15              0       en
# 492          14              2       en
# 493          18              1       en
# 494          11              0       ro
# 495          34              0       en
#
# [496 rows x 7 columns]
