# %%
import pandas as pd
import translators as ts
from tqdm.notebook import tqdm
import time

data = pd.read_excel("export_dataframe.xlsx")
#display(data)
for i in tqdm(range(len(data.index))):
    if data.iloc[i]['language'] != 'en':
        data.at[i, 'content'] = ts.translate_text(data.iloc[i]['content'], to_language='en', translator='google')
        time.sleep(0.1)
display(data)

data.to_excel('export_dataframe_translated.xlsx', index=False)
# Out:
# Using region Lower Silesia server backend.
#   0%|          | 0/501 [00:00<?, ?it/s]
#                    date                   id  \
# 0   2023-03-29 21:38:13  1641193065585975040
# 1   2023-03-29 21:32:55  1641191731084558080
# 2   2023-03-29 21:18:49  1641188183957463040
# 3   2023-03-29 21:12:00  1641186467723502080
# 4   2023-03-29 21:01:20  1641183785579601920
# ..                  ...                  ...
# 496 2023-03-28 16:38:23  1640755222183117056
# 497 2023-03-28 16:34:52  1640754338648796928
# 498 2023-03-28 16:30:01  1640753115682184960
# 499 2023-03-28 16:28:03  1640752621609950976
# 500 2023-03-28 16:25:10  1640751898625016064
#
#                                                content        username  \
# 0    feels good to win won against arcadia amp k23 ...        shoxCSGO
# 1    back to csgo until cs2 fixes the esp type comm...         n0thing
# 2                                Hagulnun is on top of  while_waiting2
# 3    Clutchza O 1V2 Pro de Eagle to guarantee the 1...  paiNGamingCSGO
# 4    cs go giveaway m4a4 neo noir to enter follow m...      The1Sancho
# ..                                                 ...             ...
# 496           you can wallbang hold long from mid on 2      JosiahCSGO
# 497  we re live with probably the last csgo season ...      remoblaser
# 498  Who is actually the IGL of the Academy Team D ...   RVMultigaming
# 499                                    Nopop CS Goka K   mameloff_csgo
# 500  glock 18 vogue csgogiveaway to enter follow re...      CsgoRudolf
#
#      like_count  retweet_count language
# 0            26              1       en
# 1            38              0       en
# 2            12             13       hu
# 3            31              0       pt
# 4            24             28       en
# ..          ...            ...      ...
# 496         357              8       en
# 497          12              0       en
# 498          18              4       de
# 499          70             13       ja
# 500         226            275       en
#
# [501 rows x 7 columns]
