# %%
import pandas as pd
import translators as ts
from tqdm.notebook import tqdm
import time

data = pd.read_excel("export_dataframe.xlsx")
#display(data)
for i in tqdm(range(len(data.index))):
    if data.iloc[i]['language'] != 'en':
        data.at[i, 'content'] = ts.translate_text(data.iloc[i]['content'], to_language='en', translator='google')
        time.sleep(0.1)
display(data)

data.to_excel('export_dataframe_translated.xlsx', index=False)
# Out:
# Using region Lower Silesia server backend.
#   0%|          | 0/500 [00:00<?, ?it/s]
#                    date                   id  \
# 0   2023-03-30 09:05:03  1641365914481316096
# 1   2023-03-30 09:01:44  1641365080582557952
# 2   2023-03-30 08:50:33  1641362264203702016
# 3   2023-03-30 08:40:46  1641359800616521984
# 4   2023-03-30 08:31:45  1641357531334476032
# ..                  ...                  ...
# 495 2023-03-28 21:45:00  1640832384697516032
# 496 2023-03-28 21:44:27  1640832247187010048
# 497 2023-03-28 21:40:11  1640831174900867072
# 498 2023-03-28 21:39:33  1640831012010618880
# 499 2023-03-28 21:38:57  1640830864845073920
#
#                                                content         username  \
# 0                                        riegl ,woletz   while_waiting2
# 1                         Win and go to the main stage    blackwiz_csgo
# 2    thank you guys for 100k. i truly appreciate th...      Maniac_CSGO
# 3    The ranks between CS2 and CSGO are unfortunate...        Dhalucard
# 4                           I want to go to CSGO AK! ✌          HiNas33
# ..                                                 ...              ...
# 495  infamous banned csgo cheater kqly received cs2...        JakeSucky
# 496  💣 | It is a real correction that will have tak...  lausanneesports
# 497  If you do APEX, you will not hit CSGO seriousl...      nazuna_kaga
# 498                                i like this content     karriganCSGO
# 499                                         ❤️❤️❤️❤️❤️     karriganCSGO
#
#      like_count  retweet_count language
# 0            16             17       de
# 1           106              8       ja
# 2            89              1       en
# 3            41              0       de
# 4            20              2       ja
# ..          ...            ...      ...
# 495        2515             40       en
# 496          21              7       fr
# 497        2145             43       ja
# 498         671              1       en
# 499        1614             14      art
#
# [500 rows x 7 columns]
